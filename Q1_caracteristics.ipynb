# %%
import pandas as pd 
df = pd.read_csv("Speed+Dating+Data.csv", encoding='latin1')
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
import plotly.io as pio
import plotly.express as px

# %%
df_10notation = df[(df["wave"] >= 6) | (df["wave"] < 10)]
df_100notation = df[(df["wave"] <6) | (df["wave"] >= 10)]
df_100notation.describe(include = "all")
# Out:
#                 iid           id       gender          idg       condtn  \
# count   6816.000000  6815.000000  6816.000000  6816.000000  6816.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     305.409624     8.952018     0.500734    17.303991     1.826291
# std      167.897804     5.517740     0.500036    10.973791     0.378887
# min        1.000000     1.000000     0.000000     1.000000     1.000000
# 25%      116.000000     4.000000     0.000000     8.000000     2.000000
# 50%      335.000000     8.000000     1.000000    16.000000     2.000000
# 75%      440.250000    13.000000     1.000000    26.000000     2.000000
# max      552.000000    22.000000     1.000000    44.000000     2.000000
#
#                wave        round     position     positin1        order  ...  \
# ...

# %%
df_male = df[df["gender"] == 1]
df_female = df[df["gender"] == 0]

# %%
attr_mean = df_male["attr1_1"].mean()
print(f"On sign_up, people declares on average that attractiviy is important on a level of {attr_mean}")
sinc_mean = df_male["sinc1_1"].mean()
print(f"On sign_up, people declares on average that sincerity is important on a level of {sinc_mean}")
intel_mean = df_male["intel1_1"].mean()
print(f"On sign_up, people declares on average that intelligence is important on a level of {intel_mean}")
fun_mean = df_male["fun1_1"].mean()
print(f"On sign_up, people declares on average that fun is important on a level of {fun_mean}")
amb_mean = df_male["amb1_1"].mean()
print(f"On sign_up, people declares on average that ambition is important on a level of {amb_mean}")
shar_mean = df_male["shar1_1"].mean()
print(f"On sign_up, people declares on average that shared interests/hobbies is important on a level of {shar_mean}")
# Out:
# On sign_up, people declares on average that attractiviy is important on a level of 26.92168902731193
# On sign_up, people declares on average that sincerity is important on a level of 16.49843555342597
# On sign_up, people declares on average that intelligence is important on a level of 19.53737422137039
# On sign_up, people declares on average that fun is important on a level of 17.76389289145053
# On sign_up, people declares on average that ambition is important on a level of 8.55282859894078
# On sign_up, people declares on average that shared interests/hobbies is important on a level of 10.996574386133847

# %%
attr_mean = df_female["attr1_1"].mean()
print(f"On sign_up, people declares on average that attractiviy is important on a level of {attr_mean}")
sinc_mean = df_female["sinc1_1"].mean()
print(f"On sign_up, people declares on average that sincerity is important on a level of {sinc_mean}")
intel_mean = df_female["intel1_1"].mean()
print(f"On sign_up, people declares on average that intelligence is important on a level of {intel_mean}")
fun_mean = df_female["fun1_1"].mean()
print(f"On sign_up, people declares on average that fun is important on a level of {fun_mean}")
amb_mean = df_female["amb1_1"].mean()
print(f"On sign_up, people declares on average that ambition is important on a level of {amb_mean}")
shar_mean = df_female["shar1_1"].mean()
print(f"On sign_up, people declares on average that shared interests/hobbies is important on a level of {shar_mean}")
# Out:
# On sign_up, people declares on average that attractiviy is important on a level of 18.05522424242424
# On sign_up, people declares on average that sincerity is important on a level of 18.305008484848486
# On sign_up, people declares on average that intelligence is important on a level of 21.00250181818182
# On sign_up, people declares on average that fun is important on a level of 17.14729212121212
# On sign_up, people declares on average that ambition is important on a level of 12.827221818181819
# On sign_up, people declares on average that shared interests/hobbies is important on a level of 12.704194491835242

# %%
#Visualiser si il y a une différente distribution en focntion de la note

attr_mean = df_10notation["attr1_1"].mean()
print(f"On sign_up, people declare on average that attractiviy is important on a level of {attr_mean}")
sinc_mean = df_10notation["sinc1_1"].mean()
print(f"On sign_up, people declare on average that sincerity is important on a level of {sinc_mean}")
intel_mean = df_10notation["intel1_1"].mean()
print(f"On sign_up, people declare on average that intelligence is important on a level of {intel_mean}")
fun_mean = df_10notation["fun1_1"].mean()
print(f"On sign_up, people declare on average that fun is important on a level of {fun_mean}")
amb_mean = df_10notation["amb1_1"].mean()
print(f"On sign_up, people declare on average that ambition is important on a level of {amb_mean}")
shar_mean = df_10notation["shar1_1"].mean()
print(f"On sign_up, people declare on average that shared interests/hobbies is important on a level of {shar_mean}")
# Out:
# On sign_up, people declare on average that attractiviy is important on a level of 22.51463188335944
# On sign_up, people declare on average that sincerity is important on a level of 17.396388721532716
# On sign_up, people declare on average that intelligence is important on a level of 20.26561272442463
# On sign_up, people declare on average that fun is important on a level of 17.45704306912776
# On sign_up, people declare on average that ambition is important on a level of 10.68253895397995
# On sign_up, people declare on average that shared interests/hobbies is important on a level of 11.845110815066004

# %%
#We can see that there are on the same scale so we analyze the complete df

# %%
#Analyser la fluctuation de réponse pour l'attractivité pour voir si on peut faire la moyenne 
attr_analyzis = [col for col in df.columns if 'attr' in col]
print(attr_analyzis)
# Out:
# ['attr_o', 'attr1_1', 'attr4_1', 'attr2_1', 'attr3_1', 'attr5_1', 'attr', 'attr1_s', 'attr3_s', 'attr7_2', 'attr1_2', 'attr4_2', 'attr2_2', 'attr3_2', 'attr5_2', 'attr1_3', 'attr7_3', 'attr4_3', 'attr2_3', 'attr3_3', 'attr5_3']

# %%
df[attr_analyzis]
# Out:
#       attr_o  attr1_1  attr4_1  attr2_1  attr3_1  attr5_1  attr  attr1_s  \
# 0        6.0     15.0      NaN     35.0      6.0      NaN   6.0      NaN
# 1        7.0     15.0      NaN     35.0      6.0      NaN   7.0      NaN
# 2       10.0     15.0      NaN     35.0      6.0      NaN   5.0      NaN
# 3        7.0     15.0      NaN     35.0      6.0      NaN   7.0      NaN
# 4        8.0     15.0      NaN     35.0      6.0      NaN   5.0      NaN
# ...      ...      ...      ...      ...      ...      ...   ...      ...
# 8373    10.0     70.0     90.0     50.0      8.0      9.0   3.0      NaN
# 8374     6.0     70.0     90.0     50.0      8.0      9.0   4.0      NaN
# 8375     2.0     70.0     90.0     50.0      8.0      9.0   4.0      NaN
# 8376     5.0     70.0     90.0     50.0      8.0      9.0   4.0      NaN
# 8377     8.0     70.0     90.0     50.0      8.0      9.0   3.0      NaN
#
#       attr3_s  attr7_2  ...  attr4_2  attr2_2  attr3_2  attr5_2  attr1_3  \
# ...

# %%
attr_mean = []
for i in attr_analyzis:
    print(df[i].mean())
    attr_mean.append(df[i].mean())
# Out:
# 6.190411462160177
# 22.51463188335944
# 26.394359685621822
# 30.362191830341008
# 7.084733470325154
# 6.941907867916837
# 6.189995107632094
# 20.791623535156248
# 7.21125
# 32.819556451612904
# 26.217194089993285
# 26.806233766233767
# 29.34436883116883
# 7.125284738041002
# 6.827964359150103
# 24.38452440865627
# 31.330357142857142
# 25.610341331530922
# 24.970936127069955
# 7.24031202818319
# 6.810019841269841

# %%
df_attr_mean = pd.DataFrame({
    "Column" : attr_analyzis,
    "Mean": attr_mean
})

df_attr_mean.head()
# Out:
#     Column       Mean
# 0   attr_o   6.190411
# 1  attr1_1  22.514632
# 2  attr4_1  26.394360
# 3  attr2_1  30.362192
# 4  attr3_1   7.084733

# %%
fig = px.bar(df_attr_mean, x= "Column", y = "Mean")
fig.show()

# %%
#Voir la fluctuation quand il y a match ou non au niveau de la réponse sur la scorecard 
attr_mean = df_female[df_female["match"] == 1]["attr"].mean()
print(f"After a date without match, people declares on average that attractiviy is important on a level of {attr_mean}")
sinc_mean = df_female[df_female["match"] == 1]["sinc"].mean()
print(f"After a date without match, people declares on average that sincerity is important on a level of {sinc_mean}")
intel_mean = df_female[df_female["match"] == 1]["intel"].mean()
print(f"After a date without match, people declares on average that intelligence is important on a level of {intel_mean}")
fun_mean = df_female[df_female["match"] == 1]["fun"].mean()
print(f"After a date without match, people declares on average that fun is important on a level of {fun_mean}")
amb_mean = df_female[df_female["match"] == 1]["amb"].mean()
print(f"After a date without match, people declares on average that ambition is important on a level of {amb_mean}")
shar_mean = df_female[df_female["match"] == 1]["shar"].mean()
print(f"After a date without match, people declares on average that shared interests/hobbies is important on a level of {shar_mean}")
# Out:
# After a date without match, people declares on average that attractiviy is important on a level of 7.118459302325581
# After a date without match, people declares on average that sincerity is important on a level of 7.820699708454811
# After a date without match, people declares on average that intelligence is important on a level of 8.075072886297376
# After a date without match, people declares on average that fun is important on a level of 7.644216691068814
# After a date without match, people declares on average that ambition is important on a level of 7.485271317829457
# After a date without match, people declares on average that shared interests/hobbies is important on a level of 6.854166666666667

# %%
attr_mean = df_female[df_female["match"] == 0]["attr"].mean()
print(f"After a date with match, people declares on average that attractiviy is important on a level of {attr_mean}")
sinc_mean = df_female[df_female["match"] == 0]["sinc"].mean()
print(f"After a date with match, people declares on average that sincerity is important on a level of {sinc_mean}")
intel_mean = df_female[df_female["match"] == 0]["intel"].mean()
print(f"After a date with match, people declares on average that intelligence is important on a level of {intel_mean}")
fun_mean = df_female[df_female["match"] == 0]["fun"].mean()
print(f"After a date with match, people declares on average that fun is important on a level of {fun_mean}")
amb_mean = df_female[df_female["match"] == 0]["amb"].mean()
print(f"After a date with match, people declares on average that ambition is important on a level of {amb_mean}")
shar_mean = df_female[df_female["match"] == 0]["shar"].mean()
print(f"After a date with match, people declares on average that shared interests/hobbies is important on a level of {shar_mean}")
# Out:
# After a date with match, people declares on average that attractiviy is important on a level of 5.676288659793815
# After a date with match, people declares on average that sincerity is important on a level of 6.952939429928741
# After a date with match, people declares on average that intelligence is important on a level of 7.318860041778573
# After a date with match, people declares on average that fun is important on a level of 5.999849306811332
# After a date with match, people declares on average that ambition is important on a level of 6.8446647780925405
# After a date with match, people declares on average that shared interests/hobbies is important on a level of 5.104390080428955

# %%
#faire la moyenne de la question 1 pour visualiser plus facilement l'importance des attributs 

attr1 = df['mean_attr_importance'] = df[['attr1_1', 'attr1_2', 'attr1_3']].mean(axis=1)
sinc1= df['mean_sinc_importance'] = df[['sinc1_1', 'sinc1_2', 'sinc1_3']].mean(axis=1)
intel1= df['mean_intel_importance'] = df[['intel1_1', 'intel1_2', 'intel1_3']].mean(axis=1)
fun1 = df['mean_fun_importance'] = df[['fun1_1', 'fun1_2', 'fun1_3']].mean(axis=1)
amb1 = df['mean_amb_importance'] = df[['amb1_1', 'amb1_2', 'amb1_3']].mean(axis=1)
shar1 = df['mean_shar_importance'] = df[['shar1_1', 'shar1_2', 'shar1_3']].mean(axis=1)
# Out:
# attr 0       16.48
# 1       16.48
# 2       16.48
# 3       16.48
# 4       16.48
#         ...
# 8373    70.00
# 8374    70.00
# 8375    70.00
# 8376    70.00
# 8377    70.00
# Length: 8378, dtype: float64 sinc 0       18.89
# 1       18.89
# 2       18.89
# 3       18.89
# 4       18.89
#         ...
# 8373     0.00
# 8374     0.00
# 8375     0.00
# 8376     0.00
# 8377     0.00
# Length: 8378, dtype: float64 intel 0       17.963333
# 1       17.963333
# 2       17.963333
# 3       17.963333
# 4       17.963333
#           ...
# 8373    16.666667
# 8374    16.666667
# 8375    16.666667
# 8376    16.666667
# 8377    16.666667
# Length: 8378, dtype: float64 amb 0       13.703333
# 1       13.703333
# 2       13.703333
# 3       13.703333
# 4       13.703333
#           ...
# 8373     0.000000
# 8374     0.000000
# 8375     0.000000
# 8376     0.000000
# 8377     0.000000
# Length: 8378, dtype: float64 shar 0       15.556667
# 1       15.556667
# 2       15.556667
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go
fig = go.Figure()

fig.add_trace(go.Histogram(x=df['mean_attr_importance'], name='Attr Importance', opacity=0.5))
fig.add_trace(go.Histogram(x=df['mean_sinc_importance'], name='Sinc Importance', opacity=0.5))
fig.add_trace(go.Histogram(x=df['mean_intel_importance'], name='Intel Importance', opacity=0.5))
fig.add_trace(go.Histogram(x=df['mean_fun_importance'], name='Fun Importance', opacity=0.5))
fig.add_trace(go.Histogram(x=df['mean_amb_importance'], name='Amb Importance', opacity=0.5))
fig.add_trace(go.Histogram(x=df['mean_shar_importance'], name='Shar Importance', opacity=0.5))

# Update layout
fig.update_layout(
    barmode='overlay',
    title='Superimposed Histogram of Various Importance Scores',
    xaxis_title='Importance Scores',
    yaxis_title='Count',
    legend_title='Importance Type(Mean)',
    template='plotly_white'
)

# Show the figure
fig.show()
